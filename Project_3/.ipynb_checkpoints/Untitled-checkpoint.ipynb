# %%
# Cell 1: Import required libraries
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Cell 2: Load the dataset
df = pd.read_csv("raw_skills.csv")
df.head()
# Out:
#              job_role                                        skills
# 0      Data Scientist  Python, SQL, Machine Learning, Data Analysis
# 1     DevOps Engineer                AWS, Docker, Kubernetes, CI/CD
# 2   Backend Developer                       Java, Python, SQL, APIs
# 3  Frontend Developer                  HTML, CSS, JavaScript, React
# 4     Cloud Architect       AWS, Azure, Cloud Computing, Automation

# %%
# Cell 3: Convert skills column into TF-IDF vectors
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(df['skills'])

# %%
# Cell 4: Take user input skills
user_input = ["Python", "Cloud", "Automation"]

# Convert to vector
user_vector = vectorizer.transform([" ".join(user_input)])

# %%
# Cell 5: Calculate similarity scores
similarity_scores = cosine_similarity(user_vector, tfidf_matrix).flatten()

# Add scores to dataframe
df['score'] = similarity_scores

# %%
# Cell 6: Show top 3 recommended job roles
recommendations = df.sort_values(by='score', ascending=False).head(3)
recommendations[['job_role', 'score']]
# Out:
#             job_role     score
# 4    Cloud Architect  0.583741
# 2  Backend Developer  0.178078
# 5        AI Engineer  0.155395

# %%
# Cell 7: Handle case when user provides no skills
if len(user_input) == 0:
    print("No skills provided. Showing trending roles:")
    print(df.sample(3)[['job_role']])
